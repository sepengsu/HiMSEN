# %%
import pandas            as pd
import numpy             as np
import seaborn           as sb
import scipy.stats       as sp
import matplotlib.pyplot as plt
pd.set_option('display.max_rows',    1000) 
pd.set_option('display.max_columns',    1000)

# %%
test_normal_mode2=pd.read_csv('./전체데이터/test_normal_mode2',sep=',')
test_normal_mode3=pd.read_csv('./전체데이터/test_normal_mode3',sep=',')
test_abnormal_mode2=pd.read_csv('./전체데이터/test_abnormal_mode2',sep=',')
test_abnormal_mode3=pd.read_csv('./전체데이터/test_abnormal_mode3',sep=',')
train_normal_mode2=pd.read_csv('./전체데이터/train_normal_mode2',sep=',')
train_normal_mode3=pd.read_csv('./전체데이터/train_normal_mode3',sep=',')
train_abnormal_mode2=pd.read_csv('./전체데이터/train_abnormal_mode2',sep=',')
train_abnormal_mode3=pd.read_csv('./전체데이터/train_abnormal_mode3',sep=',')

# %% [markdown]
# train_mode3

# %%
for i in range(0,12):
    ok=train_normal_mode3.columns[i]
    sb.kdeplot(train_normal_mode3[ok],color='blue')
    sb.kdeplot(train_abnormal_mode3[ok],color='red')
    plt.show()

# %%
for i in range(12,25):
    ok=train_normal_mode3.columns[i]
    sb.kdeplot(train_normal_mode3[ok],color='blue')
    sb.kdeplot(train_abnormal_mode3[ok],color='red')
    plt.show()
# Out:
# C:\Users\bigcompetmgr01\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\bigcompetmgr01\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\bigcompetmgr01\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
